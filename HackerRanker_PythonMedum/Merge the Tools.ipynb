# %% [markdown]
# ## Merge the Tools!
#
# Consider the following:
#
# * A string, **s**, of length **n** where **s=c0c1...cn-1.
#
# * An integer, **k**, where **k** is a factor of **n**.
#
# We can split **s** into **n/k** substrings where each subtring, **t_i**, consists of a contiguous block of **k** characters in **s**. Then, use each **t_i** to create string **u_i** such that:
#
# * The characters in **u_i** are a subsequence of the characters in **t_i**
#
# * Any repeat occurrence of a character is removed from the string such that each character in **u_i** occurs exactly once. In other words, if the character at some index **j** in **t_i** occurs at a previous index `< j` in **t_i**, then do not include the character in string **u_i**.
#
# Given **s** and **k**, print **n/k** lines where each line **i** denotes string **u_i**.
#
# ### Example
#
# **s = 'AAABCADDE'**
#
# **k = 3**
#
# There are three substrings of length **3** to consider: 'AAA', 'BCA' and 'DDE'. The first substring is all 'A' characters, so **u_1='A'**. The second substring has all distinct characters, so **u_2='BCA'**. The third substring has **2** different characters, so **u_3='DE'**. Note that a subsequence maintains the original order of characters encountered. The order of characters in each subsequence shown is important.
#
# ### Function Description
#
# Complete the merge_the_tools function in the editor below.
#
# merge_the_tools has the following parameters:
#
# * string s: the string to analyze
#
# * int k: the size of substrings to analyze
#
# ### Prints
#
# Print each subsequence on a new line. There will be **n/k** of them. No return value is expected.
#
# ### Input Format
#
# The first line contains a single string, **s**.
#
# The second line contains an integer, **k**, the length of each substring.
#
# ### Constraints
#
# * **1 <= n <= 10^4**, where **n** is the length of **s**
#
# * **1 <= k <= n**
#
# * It is guaranteed that **n** is a multiple of **k**.
#
# ### Sample Input
#
#
# STDIN       |   Function
#
#
# -----       |   --------
#
#
# AABCAAADA   |   s = 'AABCAAADA'
#
#
# 3           |   k = 3
#
# ### Sample Output
#
# AB
#
# CA
#
# AD
#
# ### Explanation
#
# Split **s** into **n/k = 9/3 = 3** equal parts of length **k=3**. Convert each **t_i** to **u_i** by removing any subsequent occurrences of non-distinct characters in **t_i**:
#
# 1. **t_0 = "AAB" --> u_0 = "AB"**
#
# 2.
#
# Print each **u_i** on a new line.

# %%
def merge_the_tools(string, k):

    sList = list(string)
    nList = []
    mList = []
    
    counter = 0
    for i in range(0, len(sList)):
        counter += 1
        if counter == k:
            counter = 0
            nList.append(''.join(sList[i-k+1:i+1]))
            
    for i in nList:
        nDict = dict()
        for j in range(0, k):
            nDict[i[j]] = nDict.get(i[j], 0) + 1
        mList += [''.join(nDict.keys())]
        
    print(mList)
    
    return ' '.join(mList)

# %%
string = "AABCAAADA"
k = 3
merge_the_tools(string, k)
# Out:
# ['AB', 'CA', 'AD']
# 'AB CA AD'

# %% [markdown]
# AB
#
# CA
#
# AD

# %%
string = "..."
k = 3452
merge_the_tools(string, k)
# Out:
# ['KYQTWXDLINFBHRGZVCUSAMOEPJ', 'YUGTZIWNVSALBXOCDMPFEKJRQH']
# 'KYQTWXDLINFBHRGZVCUSAMOEPJ YUGTZIWNVSALBXOCDMPFEKJRQH'

# %% [markdown]
# KYQTWXDLINFBHRGZVCUSAMOEPJ
#
# YUGTZIWNVSALBXOCDMPFEKJRQH

# %%
string = "..."
k = 1246
merge_the_tools(string, k)
# Out:
# ['RDITWGZKCEXNHSAUJYOFQMPVBL', 'DOVIKJPRGYHZQXBMEUALCTSWFN', 'JBCLGFUSTDOKYIRZVAEXPWMQNH', 'OQNIBFLHXZSRJMDETWGYVPUACK', 'LBSTKUYVHMZQAXGJPCNOEWDIRF', 'OYPZVRFKDEUQSIBAXGLJWMNCHT', 'WRDSMQIGZXHEOBACFNVUKJPYTL', 'EDQNUKVBRSLGWZOAMXIHJYCTFP']
# 'RDITWGZKCEXNHSAUJYOFQMPVBL DOVIKJPRGYHZQXBMEUALCTSWFN JBCLGFUSTDOKYIRZVAEXPWMQNH OQNIBFLHXZSRJMDETWGYVPUACK LBSTKUYVHMZQAXGJPCNOEWDIRF OYPZVRFKDEUQSIBAXGLJWMNCHT WRDSMQIGZXHEOBACFNVUKJPYTL EDQNUKVBRSLGWZOAMXIHJYCTFP'

# %% [markdown]
# RDITWGZKCEXNHSAUJYOFQMPVBL
#
# DOVIKJPRGYHZQXBMEUALCTSWFN
#
# JBCLGFUSTDOKYIRZVAEXPWMQNH
#
# OQNIBFLHXZSRJMDETWGYVPUACK
#
# LBSTKUYVHMZQAXGJPCNOEWDIRF
#
# OYPZVRFKDEUQSIBAXGLJWMNCHT
#
# WRDSMQIGZXHEOBACFNVUKJPYTL
#
# EDQNUKVBRSLGWZOAMXIHJYCTFP

# %%
string = "..."
k = 5424
merge_the_tools(string, k)
# Out:
# ['BWMNAKIJHOZXVGQYPLCEUDSFTR']
# 'BWMNAKIJHOZXVGQYPLCEUDSFTR'

# %% [markdown]
# BWMNAKIJHOZXVGQYPLCEUDSFTR

# %%
string = "..."
k = 3333
merge_the_tools(string, k)
# Out:
# ['UWFDSVEPZHBAQTXGRMNCYLJIKO', 'LROTJNQKHAEIUGZDWSBXCVMYPF', 'PLAUVDWFYKHRNJOMEXIZQSGCBT']
# 'UWFDSVEPZHBAQTXGRMNCYLJIKO LROTJNQKHAEIUGZDWSBXCVMYPF PLAUVDWFYKHRNJOMEXIZQSGCBT'

# %% [markdown]
# UWFDSVEPZHBAQTXGRMNCYLJIKO
#
# LROTJNQKHAEIUGZDWSBXCVMYPF
#
# PLAUVDWFYKHRNJOMEXIZQSGCBT

# %%
string = "..."
k = 6623
merge_the_tools(string, k)
# Out:
# ['DWNFMZVQPKGXESLIUCJROHYBTA']
# 'DWNFMZVQPKGXESLIUCJROHYBTA'

# %% [markdown]
# DWNFMZVQPKGXESLIUCJROHYBTA

# %%
string = "..."
k = 1007
merge_the_tools(string, k)
# Out:
# ['RTQXLDVWHFIGNCJMEKOZPSYABU', 'PHVXEZKOYDUNGQJILCTFMBSAWR', 'ALDPBUYHFGZRTVCOWKMXNIQJES', 'YJEPQGSUVBWOZTNRFCMHDKILXA', 'TVEDPWHAMJKBFSUXYQIGZNORCL', 'RVKGNEJMCYXSLZUTPIWBFDHQAO', 'TEQDVRWMAPOGJUHKLYXZCNBFSI', 'ETXSOVULBPQGCKAINWMHJRFDYZ', 'AKEFBPXIRQHZMDOYTUVWJGLSNC']
# 'RTQXLDVWHFIGNCJMEKOZPSYABU PHVXEZKOYDUNGQJILCTFMBSAWR ALDPBUYHFGZRTVCOWKMXNIQJES YJEPQGSUVBWOZTNRFCMHDKILXA TVEDPWHAMJKBFSUXYQIGZNORCL RVKGNEJMCYXSLZUTPIWBFDHQAO TEQDVRWMAPOGJUHKLYXZCNBFSI ETXSOVULBPQGCKAINWMHJRFDYZ AKEFBPXIRQHZMDOYTUVWJGLSNC'

# %% [markdown]
# RTQXLDVWHFIGNCJMEKOZPSYABU
#
# PHVXEZKOYDUNGQJILCTFMBSAWR
#
# ALDPBUYHFGZRTVCOWKMXNIQJES
#
# YJEPQGSUVBWOZTNRFCMHDKILXA
#
# TVEDPWHAMJKBFSUXYQIGZNORCL
#
# RVKGNEJMCYXSLZUTPIWBFDHQAO
#
# TEQDVRWMAPOGJUHKLYXZCNBFSI
#
# ETXSOVULBPQGCKAINWMHJRFDYZ
#
# AKEFBPXIRQHZMDOYTUVWJGLSNC
