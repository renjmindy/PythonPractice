# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
df.index
# Out:
# RangeIndex(start=0, stop=197625, step=1)

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   197625 non-null  object
#  1   UNIT                                                                  197625 non-null  object
#  2   SCP                                                                   197625 non-null  object
#  3   STATION                                                               197625 non-null  object
#  4   LINENAME                                                              197625 non-null  object
#  5   DIVISION                                                              197625 non-null  object
#  6   DATE                                                                  197625 non-null  object
#  7   TIME                                                                  197625 non-null  object
#  8   DESC                                                                  197625 non-null  object
#  9   ENTRIES                                                               197625 non-null  int64
#  10  EXITS                                                                 197625 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %%
df.describe()
# Out:
#             ENTRIES  \
# count  1.976250e+05
# mean   4.008664e+07
# std    2.071853e+08
# min    0.000000e+00
# 25%    4.912700e+05
# 50%    2.507222e+06
# 75%    6.965458e+06
# max    2.129771e+09
#
#        EXITS
# count                                       1.976250e+05
# mean                                        3.274210e+07
# std                                         1.907195e+08
# min                                         0.000000e+00
# 25%                                         2.364400e+05
# 50%                                         1.404800e+06
# 75%                                         4.809089e+06
# max                                         2.062565e+09

# %%
df.isnull().value_counts()
# Out:
# C/A    UNIT   SCP    STATION  LINENAME  DIVISION  DATE   TIME   DESC   ENTRIES  EXITS
# False  False  False  False    False     False     False  False  False  False    False                                                                   197625
# dtype: int64

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().values.all()
# Out:
# False

# %% [markdown]
# Rename all the columns to lower case:

# %%
# Rename all the columns to lower case
df.columns = list(name.lower() for name in df.columns)

# %%
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df = df.set_index('linename')

# %%
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df = df.reset_index()

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df['num_lines'] = df['linename'].map(lambda x:len(x))
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    num_lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = col_name.strip()
    return cleaned

# %%
# Use the above function to clean the column names
df.columns = list(clean(name) for name in df.columns)

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'num_lines'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
df['date'] = pd.to_datetime(df['date'])

# Add a new column 'day_of_week' that represents the day of the week 
df['day_of_week'] = df['date'].dt.dayofweek

# %%
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'num_lines', 'day_of_week'],
#       dtype='object')

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division       date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  num_lines  day_of_week
# 0  REGULAR  6736067  2283184          7            5
# 1  REGULAR  6736087  2283188          7            5
# 2  REGULAR  6736105  2283229          7            5
# 3  REGULAR  6736180  2283314          7            5
# 4  REGULAR  6736349  2283384          7            5

# %%
grouped = df.groupby('day_of_week')
grouped.head()
# Out:
#    linename   c/a  unit       scp station division       date      time  \
# 0   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
# 6   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-26  00:00:00
# 7   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-26  04:00:00
# 8   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-26  08:00:00
# 9   NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-26  12:00:00
# 10  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-26  16:00:00
# 12  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-27  00:00:00
# 13  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-27  04:00:00
# 14  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-27  08:00:00
# 15  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-27  12:00:00
# 16  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-27  16:00:00
# 18  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-28  00:00:00
# 19  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-28  04:00:00
# 20  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-28  08:00:00
# 21  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-28  12:00:00
# 22  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-28  16:00:00
# 24  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-29  00:00:00
# 25  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-29  04:00:00
# 26  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-29  08:00:00
# 27  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-29  12:00:00
# 28  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-29  16:00:00
# 30  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-30  00:00:00
# 31  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-30  04:00:00
# 32  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-30  08:00:00
# 33  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-30  12:00:00
# 34  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-30  16:00:00
# 36  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-31  00:00:00
# 37  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-31  04:00:00
# 38  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-31  08:00:00
# 39  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-31  12:00:00
# 40  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-31  16:00:00
#
#        desc  entries    exits  num_lines  day_of_week
# 0   REGULAR  6736067  2283184          7            5
# 1   REGULAR  6736087  2283188          7            5
# 2   REGULAR  6736105  2283229          7            5
# 3   REGULAR  6736180  2283314          7            5
# 4   REGULAR  6736349  2283384          7            5
# 6   REGULAR  6736683  2283460          7            6
# 7   REGULAR  6736696  2283461          7            6
# 8   REGULAR  6736705  2283483          7            6
# 9   REGULAR  6736746  2283524          7            6
# 10  REGULAR  6736873  2283587          7            6
# 12  REGULAR  6737136  2283656          7            0
# 13  REGULAR  6737146  2283658          7            0
# 14  REGULAR  6737169  2283736          7            0
# 15  REGULAR  6737301  2283965          7            0
# 16  REGULAR  6737553  2284025          7            0
# 18  REGULAR  6738430  2284121          7            1
# 19  REGULAR  6738442  2284126          7            1
# 20  REGULAR  6738474  2284216          7            1
# 21  REGULAR  6738621  2284402          7            1
# 22  REGULAR  6738886  2284425          7            1
# 24  REGULAR  6739804  2284508          7            2
# 25  REGULAR  6739812  2284512          7            2
# 26  REGULAR  6739847  2284600          7            2
# 27  REGULAR  6739986  2284838          7            2
# 28  REGULAR  6740257  2284896          7            2
# 30  REGULAR  6741065  2284964          7            3
# 31  REGULAR  6741082  2284967          7            3
# 32  REGULAR  6741115  2285052          7            3
# 33  REGULAR  6741241  2285273          7            3
# 34  REGULAR  6741533  2285329          7            3
# 36  REGULAR  6742397  2285424          7            4
# 37  REGULAR  6742410  2285426          7            4
# 38  REGULAR  6742444  2285498          7            4
# 39  REGULAR  6742575  2285689          7            4
# 40  REGULAR  6743014  2285766          7            4

# %%
grouped_sum = df.groupby('day_of_week').sum()
grouped_sum.head()
# Out:
#                    entries         exits  num_lines
# day_of_week
# 0            1114237052454  911938153513      76110
# 1            1143313287046  942230721477      77303
# 2            1123655222441  920630864687      75713
# 3            1122723988662  920691927110      76607
# 4            1110224700078  906799065337      75573

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped_sum = df.groupby('day_of_week').sum()
grouped_sum.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped_sum = grouped_sum.reset_index()

# Print the first five rows of grouped
grouped_sum.head()
# Out:
#    day_of_week        entries         exits  num_lines
# 0            0  1114237052454  911938153513      76110
# 1            1  1143313287046  942230721477      77303
# 2            2  1123655222441  920630864687      75713
# 3            3  1122723988662  920691927110      76607
# 4            4  1110224700078  906799065337      75573

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped_sum['is_weekend'] = grouped_sum['day_of_week'].map(weekend_map)
grouped_sum.head()
# Out:
#    day_of_week        entries         exits  num_lines  is_weekend
# 0            0  1114237052454  911938153513      76110       False
# 1            1  1143313287046  942230721477      77303       False
# 2            2  1123655222441  920630864687      75713       False
# 3            3  1122723988662  920691927110      76607       False
# 4            4  1110224700078  906799065337      75573       False

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped_sum.groupby('is_weekend').sum()
wkend[['entries', 'exits']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = df.drop(['c/a', 'scp'], axis=1)
df.head(2)
# Out:
#   linename  unit station division       date      time     desc  entries  \
# 0  NQR456W  R051   59 ST      BMT 2018-08-25  00:00:00  REGULAR  6736067
# 1  NQR456W  R051   59 ST      BMT 2018-08-25  04:00:00  REGULAR  6736087
#
#      exits  num_lines  day_of_week
# 0  2283184          7            5
# 1  2283188          7            5

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here 
# The raw data for entries/exits is cumulative. 
# As such, you would first need to order the data by time and station, 
# and then calculate the difference in order to produce meaningful aggregations.

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
